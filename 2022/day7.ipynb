# %%
from aocd import get_data, submit
data = get_data(year=2022, day=7).splitlines()

# %%
tree = {}
pwd = []
make_pwd = lambda pwd: "/" + "/".join(pwd)


for line in data:
    if line.startswith("$ cd"):
        if line == "$ cd /":
            pwd = []
            continue
        new_dir = line.split(" ")[2]
        if new_dir == "..":
            pwd.pop()
        else: 
            pwd.append(new_dir)        
    elif line.startswith("$ ls"):
        pass
    elif line.startswith("dir"):
        p = make_pwd(pwd)
        dir_name = line.split(" ")[1]
        dir_name = make_pwd(pwd + [dir_name])
        if p in tree:
            tree[p].append(dir_name)
        else: 
            tree[p] = [dir_name]
    else: 
        file_size, file_name = line.split(" ")
        file_size = int(file_size)
        if (p := make_pwd(pwd)) in tree:
            tree[p].append(file_size)
        else:
            tree[p] = [file_size]
# Out:
# {'/': [268495,
#   '/ltcqgnc',
#   272455,
#   200036,
#   174378,
#   '/rbmstsf',
#   130541,
#   '/twjcmp'],
#  '/ltcqgnc': [227634,
#   '/ltcqgnc/cmdzcq',
#   '/ltcqgnc/dnbf',
#   203609,
#   '/ltcqgnc/frt',
#   288222,
#   '/ltcqgnc/ngm',
#   '/ltcqgnc/ngsrlzc',
#   5927,
#   '/ltcqgnc/shjv',
#   '/ltcqgnc/wsvfbb'],
#  '/ltcqgnc/cmdzcq': [37316,
#   41839,
#   '/ltcqgnc/cmdzcq/pfmbt',
#   281659,
#   '/ltcqgnc/cmdzcq/vmd',
#   189667],
#  '/ltcqgnc/cmdzcq/pfmbt': [120151, 45035],
#  '/ltcqgnc/cmdzcq/vmd': ['/ltcqgnc/cmdzcq/vmd/dnc',
#   '/ltcqgnc/cmdzcq/vmd/rgftffp'],
#  '/ltcqgnc/cmdzcq/vmd/dnc': ['/ltcqgnc/cmdzcq/vmd/dnc/dvndwjzs',
#   216199,
#   '/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg',
#   '/ltcqgnc/cmdzcq/vmd/dnc/lsfn',
#   '/ltcqgnc/cmdzcq/vmd/dnc/lzcv',
#   237080,
#   131509,
#   84024],
#  '/ltcqgnc/cmdzcq/vmd/dnc/dvndwjzs': [264750],
#  '/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg': ['/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg/cfvhc',
#   285900,
#   112604,
#   188180,
#   '/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg/prgbvj'],
#  '/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg/cfvhc': [136528],
#  '/ltcqgnc/cmdzcq/vmd/dnc/gwhtzlpg/prgbvj': [180538],
#  '/ltcqgnc/cmdzcq/vmd/dnc/lsfn': [133375, 242940],
#  '/ltcqgnc/cmdzcq/vmd/dnc/lzcv': [121565, 100302],
#  '/ltcqgnc/cmdzcq/vmd/rgftffp': [259406],
#  '/ltcqgnc/dnbf': ['/ltcqgnc/dnbf/bft',
#   219468,
#   130503,
#   120522,
#   92338,
#   '/ltcqgnc/dnbf/vpmvnmfj'],
#  '/ltcqgnc/dnbf/bft': ['/ltcqgnc/dnbf/bft/zdvj'],
/rbmstsf/bbsmm/rfjfp/lhf/rmsggp',
#   49093,
#   '/rbmstsf/bbsmm/rfjfp/lhf/tmf',
#   '/rbmstsf/bbsmm/rfjfp/lhf/zdvj'],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp': ['/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq',
#   '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/lhghnn',
#   '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/zdvj'],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq': ['/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/wqzwsspq',
#   '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/zdvj'],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/wqzwsspq': ['/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/wqzwsspq/gbzfpfq'],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/wqzwsspq/gbzfpfq': [185410],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/fznsmbq/zdvj': [140384],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/lhghnn': [36868, 181925],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/zdvj': [256916,
#   '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/zdvj/rwhffw',
#   75846],
#  '/rbmstsf/bbsmm/rfjfp/lhf/rmsggp/zdvj/rwhffw': [234834, 140315],
#  '/rbmstsf/bbsmm/rfjfp/lhf/tmf': [88583, 52796],
#  '/rbmstsf/bbsmm/rfjfp/lhf/zdvj': [8822, 221658],
#  '/rbmstsf/bbsmm/rfjfp/qld': [119026,
#   87684,
#   '/rbmstsf/bbsmm/rfjfp/qld/zdvj',
#   212120],
#  '/rbmstsf/bbsmm/rfjfp/qld/zdvj': ['/rbmstsf/bbsmm/rfjfp/qld/zdvj/cfvhc',
#   169434],
#  '/rbmstsf/bbsmm/rfjfp/qld/zdvj/cfvhc': [243919],
#  '/rbmstsf/bbsmm/rfjfp/qwzj': [101395],
#  '/rbmstsf/bbsmm/rwhffw': [94012,
#   205816,
#   '/rbmstsf/bbsmm/rwhffw/lzbmzw',
#   155203],
#  '/rbmstsf/bbsmm/rwhffw/lzbmzw': ['/rbmstsf/bbsmm/rwhffw/lzbmzw/dfrdczdj'],
#  '/rbmstsf/bbsmm/rwhffw/lzbmzw/dfrdczdj': [126459],
#  '/rbmstsf/bbsmm/sbfshph': [229389, 135997, 119490, 94530],
#  '/rbmstsf/cfvhc': ['/rbmstsf/cfvhc/cmr',
#   '/rbmstsf/cfvhc/jvh',
#   '/rbmstsf/cfvhc/mjs'],
#  '/rbmstsf/cfvhc/cmr': [227026],
#  '/rbmstsf/cfvhc/jvh': ['/rbmstsf/cfvhc/jvh/qld'],
#  '/rbmstsf/cfvhc/jvh/qld': [96968],
#  '/rbmstsf/cfvhc/mjs': [98117],
#  '/rbmstsf/mgzl': [198793],
#  '/rbmstsf/ngflwbmp': ['/rbmstsf/ngflwbmp/bbsmm',
#   '/rbmstsf/ngflwbmp/jthnmqs',
#   137176,
#   80344,
#   133166,
#   210691,
#   255501,
#   '/rbmstsf/ngflwbmp/zdvj'],
#  '/rbmstsf/ngflwbmp/bbsmm': [98501, 134593, 46020, 213591],
#  '/rbmstsf/ngflwbmp/jthnmqs': ['/rbmstsf/ngflwbmp/jthnmqs/bbsmm',
#   '/rbmstsf/ngflwbmp/jthnmqs/cfdbp',
#   '/rbmstsf/ngflwbmp/jthnmqs/dpwqmbw',
#   67233,
#   21344,
#   '/rbmstsf/ngflwbmp/jthnmqs/rwhffw',
#   '/rbmstsf/ngflwbmp/jthnmqs/sdtntw',
#   268059,
#   '/rbmstsf/ngflwbmp/jthnmqs/zdvj'],
#  '/rbmstsf/ngflwbmp/jthnmqs/bbsmm': [263767, 46528],
#  '/rbmstsf/ngflwbmp/jthnmqs/cfdbp': ['/rbmstsf/ngflwbmp/jthnmqs/cfdbp/grczc'],
#  '/rbmstsf/ngflwbmp/jthnmqs/cfdbp/grczc': [241829],
#  '/rbmstsf/ngflwbmp/jthnmqs/dpwqmbw': [287899],
#  '/rbmstsf/ngflwbmp/jthnmqs/rwhffw': [41741,
#   '/rbmstsf/ngflwbmp/jthnmqs/rwhffw/ffzc',
#   '/rbmstsf/ngflwbmp/jthnmqs/rwhffw/nrs',
#   279620],
#  '/rbmstsf/ngflwbmp/jthnmqs/rwhffw/ffzc': [10583],
#  '/rbmstsf/ngflwbmp/jthnmqs/rwhffw/nrs': [195239],
#  '/rbmstsf/ngflwbmp/jthnmqs/sdtntw': [245601, 9552],
#  '/rbmstsf/ngflwbmp/jthnmqs/zdvj': ['/rbmstsf/ngflwbmp/jthnmqs/zdvj/smjvcql'],
#  '/rbmstsf/ngflwbmp/jthnmqs/zdvj/smjvcql': ['/rbmstsf/ngflwbmp/jthnmqs/zdvj/smjvcql/qcqljj'],
#  '/rbmstsf/ngflwbmp/jthnmqs/zdvj/smjvcql/qcqljj': [286791],
#  '/rbmstsf/ngflwbmp/zdvj': ['/rbmstsf/ngflwbmp/zdvj/bcghd',
#   57663,
#   177473,
#   53543,
#   251188,
#   '/rbmstsf/ngflwbmp/zdvj/snqjl'],
#  '/rbmstsf/ngflwbmp/zdvj/bcghd': [106732,
#   '/rbmstsf/ngflwbmp/zdvj/bcghd/vtgsnb'],
#  '/rbmstsf/ngflwbmp/zdvj/bcghd/vtgsnb': ['/rbmstsf/ngflwbmp/zdvj/bcghd/vtgsnb/gtj'],
#  '/rbmstsf/ngflwbmp/zdvj/bcghd/vtgsnb/gtj': [151689],
#  '/rbmstsf/ngflwbmp/zdvj/snqjl': [104993, 233367, 11942],
#  '/rbmstsf/shvjprl': [130539],
#  '/twjcmp': [86053]}

# %%
folder_sizes = {}
def find_size_recursive(path):
    size = 0
    for file in tree[path]:
        if isinstance(file, str):
            size += find_size_recursive(file)
        else: 
            size += file
    folder_sizes[path] = size
    return size
find_size_recursive("/")
# Out:
# 43598596

# %%
threshold = 100000
get_answer = lambda folder_sizes: sum(f for f in folder_sizes.values() if f <= 100000)
answer = get_answer(folder_sizes)
answer
# Out:
# 1582412

# %%
submit(answer, year=2022, day=7, part="a")
# Out:
# Part a already solved with same answer: 1582412

# %%
used = folder_sizes["/"]
available_space = 70000000
needed_free =    30000000
target = available_space - needed_free
to_delete = used - target
to_delete
# Out:
# 3598596

# %%
size_list = list(zip(folder_sizes.keys(), folder_sizes.values()))
smallest = 1e9
best_dir = ""
for dir_name, size in size_list:
    if (size > to_delete) and (size < smallest):
        best_dir = dir_name
        smallest = size
best_dir, smallest
# Out:
# ('/ltcqgnc/ngm/zdvj/hzzs', 3696336)

# %%
submit(smallest, year=2022, day=7, part="b")
# Out:
# Part b already solved with same answer: 3696336
